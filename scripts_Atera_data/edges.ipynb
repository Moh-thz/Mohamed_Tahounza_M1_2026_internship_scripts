# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os
from pathlib import Path
from tysserand import tysserand as ty

# %%
def nodes_to_edges_unique(dossier_nodes,chemin_resultats, fichier):
#fonction pour enregistrer dans un dossier les edges des nodes d'un dossier 
#emplacement = path où se trouvent les nodes
#fichier = nom fichier du fichier nodes
#chemin_résultats = Path vers où on veut save les edges

    # Delaunay triangulation
    nodes = pd.read_parquet(dossier_nodes, columns=['x_centroid','y_centroid', 'group'])
    coords = nodes.loc[:,['x_centroid','y_centroid']].values
    pairs = ty.build_delaunay(coords)
    distances = ty.distance_neighbors(coords, pairs)
    
    #récupération des indices comme id car delaunay reset les indices et on perd correspondance
    node_ids = nodes.index.to_numpy()
    pairs_ids = node_ids[pairs]
    edges = ty.pairs_to_df(pairs_ids)
    #enregistrer edges
    fichier = fichier.replace('nodes','edges')
    chemin = os.path.join(chemin_resultats, fichier)
    edges.to_parquet(chemin)

def nodes_to_edges_dossier(dossier_nodes,chemin_resultats):
    for fichier in os.listdir(dossier_nodes):
        if not (fichier.startswith("nodes") and fichier.endswith(".parquet")):
            continue
        emplacement = os.path.join(dossier_nodes, fichier)
        nodes_to_edges_unique(emplacement,chemin_resultats,fichier)

# %%
#éxécuter fonction
dossier_nodes = Path("./nodes/chunks/5000/chunks/16chunks_adjusted")
chemin_resultats = Path("./OUTPUT/chunk_5000/16_chunks/edges_tysserand")
chemin_resultats.mkdir(parents= True, exist_ok= True)

nodes_to_edges_dossier(dossier_nodes, chemin_resultats)

# %%
test = pd.read_parquet('./OUTPUT/1000_edges_tysserand/edges_patient-01_sample-01.parquet')
edges = test

# %%
test['source'].unique()
print(edges["source"].min(), edges["source"].max())
print(edges["target"].min(), edges["target"].max())
# Out:
# 0 689201
# 0 689201

# %%
test['source'].unique()
print(edges["source"].min(), edges["source"].max())
print(edges["target"].min(), edges["target"].max())
# Out:
# 0 689201
# 0 689201
